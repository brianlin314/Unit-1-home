# %%
import numpy as np
import pandas as pd
from scipy.stats import pearsonr
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import chi2, mutual_info_classif, RFE, SelectFromModel, SelectKBest, VarianceThreshold
from sklearn.linear_model import LogisticRegression
import warnings

# %%
pd.set_option('display.max_columns', None)
pd.options.mode.use_inf_as_na = True
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/SSD/p76111262/all_filtered_data.csv')

# %%
columns_to_delete = ['Flow ID', 'Src IP', 'Src Port', 'Dst IP']
data.drop(columns_to_delete, axis=1, inplace=True)

# %% [markdown]
# # 数据预处理

# %%
numerical_fea = list(data.select_dtypes(exclude=['object']).columns)
category_fea = list(filter(lambda x: x not in numerical_fea, list(data.columns)))

# %%
def get_numerical_serial_fea(data, feas):
    numerical_serial_fea = []
    numerical_noserial_fea = []
    for fea in feas:
        temp = data[fea].nunique()
        if temp <= 10:
            numerical_noserial_fea.append(fea)
        else:
            numerical_serial_fea.append(fea)
    return numerical_serial_fea, numerical_noserial_fea
numerical_serial_fea, numerical_noserial_fea = get_numerical_serial_fea(data, numerical_fea)

# %%
data.isnull().sum().to_dict()
# Out:
# {'Dst Port': 0,
#  'Protocol': 0,
#  'Timestamp': 0,
#  'Flow Duration': 0,
#  'Tot Fwd Pkts': 0,
#  'Tot Bwd Pkts': 0,
#  'TotLen Fwd Pkts': 0,
#  'TotLen Bwd Pkts': 0,
#  'Fwd Pkt Len Max': 0,
#  'Fwd Pkt Len Min': 0,
#  'Fwd Pkt Len Mean': 0,
#  'Fwd Pkt Len Std': 0,
#  'Bwd Pkt Len Max': 0,
#  'Bwd Pkt Len Min': 0,
#  'Bwd Pkt Len Mean': 0,
#  'Bwd Pkt Len Std': 0,
#  'Flow Byts/s': 19,
#  'Flow Pkts/s': 19,
#  'Flow IAT Mean': 0,
#  'Flow IAT Std': 0,
#  'Flow IAT Max': 0,
#  'Flow IAT Min': 0,
#  'Fwd IAT Tot': 0,
#  'Fwd IAT Mean': 0,
#  'Fwd IAT Std': 0,
#  'Fwd IAT Max': 0,
#  'Fwd IAT Min': 0,
#  'Bwd IAT Tot': 0,
#  'Bwd IAT Mean': 0,
#  'Bwd IAT Std': 0,
#  'Bwd IAT Max': 0,
#  'Bwd IAT Min': 0,
#  'Fwd PSH Flags': 0,
#  'Bwd PSH Flags': 0,
#  'Fwd URG Flags': 0,
#  'Bwd URG Flags': 0,
#  'Fwd Header Len': 0,
#  'Bwd Header Len': 0,
#  'Fwd Pkts/s': 0,
#  'Bwd Pkts/s': 0,
#  'Pkt Len Min': 0,
#  'Pkt Len Max': 0,
#  'Pkt Len Mean': 0,
#  'Pkt Len Std': 0,
#  'Pkt Len Var': 0,
#  'FIN Flag Cnt': 0,
#  'SYN Flag Cnt': 0,
#  'RST Flag Cnt': 0,
#  'PSH Flag Cnt': 0,
#  'ACK Flag Cnt': 0,
#  'URG Flag Cnt': 0,
#  'CWE Flag Count': 0,
#  'ECE Flag Cnt': 0,
#  'Down/Up Ratio': 0,
#  'Pkt Size Avg': 0,
#  'Fwd Seg Size Avg': 0,
#  'Bwd Seg Size Avg': 0,
#  'Fwd Byts/b Avg': 0,
#  'Fwd Pkts/b Avg': 0,
#  'Fwd Blk Rate Avg': 0,
#  'Bwd Byts/b Avg': 0,
#  'Bwd Pkts/b Avg': 0,
#  'Bwd Blk Rate Avg': 0,
#  'Subflow Fwd Pkts': 0,
#  'Subflow Fwd Byts': 0,
#  'Subflow Bwd Pkts': 0,
#  'Subflow Bwd Byts': 0,
#  'Init Fwd Win Byts': 0,
#  'Init Bwd Win Byts': 0,
#  'Fwd Act Data Pkts': 0,
#  'Fwd Seg Size Min': 0,
#  'Active Mean': 0,
#  'Active Std': 0,
#  'Active Max': 0,
#  'Active Min': 0,
#  'Idle Mean': 0,
#  'Idle Std': 0,
#  'Idle Max': 0,
#  'Idle Min': 0,
#  'Label': 0}

# %%
data[numerical_serial_fea] = data[numerical_serial_fea].fillna(data[numerical_serial_fea].mean())

# %%
data.isnull().sum().to_dict()
# Out:
# {'Dst Port': 0,
#  'Protocol': 0,
#  'Timestamp': 0,
#  'Flow Duration': 0,
#  'Tot Fwd Pkts': 0,
#  'Tot Bwd Pkts': 0,
#  'TotLen Fwd Pkts': 0,
#  'TotLen Bwd Pkts': 0,
#  'Fwd Pkt Len Max': 0,
#  'Fwd Pkt Len Min': 0,
#  'Fwd Pkt Len Mean': 0,
#  'Fwd Pkt Len Std': 0,
#  'Bwd Pkt Len Max': 0,
#  'Bwd Pkt Len Min': 0,
#  'Bwd Pkt Len Mean': 0,
#  'Bwd Pkt Len Std': 0,
#  'Flow Byts/s': 0,
#  'Flow Pkts/s': 0,
#  'Flow IAT Mean': 0,
#  'Flow IAT Std': 0,
#  'Flow IAT Max': 0,
#  'Flow IAT Min': 0,
#  'Fwd IAT Tot': 0,
#  'Fwd IAT Mean': 0,
#  'Fwd IAT Std': 0,
#  'Fwd IAT Max': 0,
#  'Fwd IAT Min': 0,
#  'Bwd IAT Tot': 0,
#  'Bwd IAT Mean': 0,
#  'Bwd IAT Std': 0,
#  'Bwd IAT Max': 0,
#  'Bwd IAT Min': 0,
#  'Fwd PSH Flags': 0,
#  'Bwd PSH Flags': 0,
#  'Fwd URG Flags': 0,
#  'Bwd URG Flags': 0,
#  'Fwd Header Len': 0,
#  'Bwd Header Len': 0,
#  'Fwd Pkts/s': 0,
#  'Bwd Pkts/s': 0,
#  'Pkt Len Min': 0,
#  'Pkt Len Max': 0,
#  'Pkt Len Mean': 0,
#  'Pkt Len Std': 0,
#  'Pkt Len Var': 0,
#  'FIN Flag Cnt': 0,
#  'SYN Flag Cnt': 0,
#  'RST Flag Cnt': 0,
#  'PSH Flag Cnt': 0,
#  'ACK Flag Cnt': 0,
#  'URG Flag Cnt': 0,
#  'CWE Flag Count': 0,
#  'ECE Flag Cnt': 0,
#  'Down/Up Ratio': 0,
#  'Pkt Size Avg': 0,
#  'Fwd Seg Size Avg': 0,
#  'Bwd Seg Size Avg': 0,
#  'Fwd Byts/b Avg': 0,
#  'Fwd Pkts/b Avg': 0,
#  'Fwd Blk Rate Avg': 0,
#  'Bwd Byts/b Avg': 0,
#  'Bwd Pkts/b Avg': 0,
#  'Bwd Blk Rate Avg': 0,
#  'Subflow Fwd Pkts': 0,
#  'Subflow Fwd Byts': 0,
#  'Subflow Bwd Pkts': 0,
#  'Subflow Bwd Byts': 0,
#  'Init Fwd Win Byts': 0,
#  'Init Bwd Win Byts': 0,
#  'Fwd Act Data Pkts': 0,
#  'Fwd Seg Size Min': 0,
#  'Active Mean': 0,
#  'Active Std': 0,
#  'Active Max': 0,
#  'Active Min': 0,
#  'Idle Mean': 0,
#  'Idle Std': 0,
#  'Idle Max': 0,
#  'Idle Min': 0,
#  'Label': 0}

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'],format='%d/%m/%Y %H:%M:%S')

# %%
from sklearn.preprocessing import LabelEncoder

# 初始化LabelEncoder
label_encoder = LabelEncoder()

# 将标签编码为整数
data['Label'] = label_encoder.fit_transform(data['Label'])

# %% [markdown]
# # 异常值处理

# %%
def find_outliers_by_3segama(data, fea):
    data_std = np.std(data[fea])
    data_mean = np.mean(data[fea])
    outliers_cut_off = 3 * data_std
    lower_rule = data_mean - outliers_cut_off
    upper_rule = data_mean + outliers_cut_off
    data[fea+'_outliers'] = data[fea].apply(lambda x: int(1) if x > upper_rule or x < lower_rule else int(0))
    return data

# %%
for fea in numerical_serial_fea:
    data = find_outliers_by_3segama(data, fea)
    print(data[fea+'_outliers'].value_counts())
    print(data.groupby(fea+'_outliers')['Label'].sum())
    print('*'*10)
# Out:
# 0    636463
# 1      3537
# Name: Dst Port_outliers, dtype: int64
# Dst Port_outliers
# 0    4040640
# 1       8272
# Name: Label, dtype: int64
# **********
# 0    629958
# 1     10042
# Name: Flow Duration_outliers, dtype: int64
# Flow Duration_outliers
# 0    3991551
# 1      57361
# Name: Label, dtype: int64
# **********
# 0    639631
# 1       369
# Name: Tot Fwd Pkts_outliers, dtype: int64
# Tot Fwd Pkts_outliers
# 0    4047402
# 1       1510
# Name: Label, dtype: int64
# **********
# 0    636285
# 1      3715
# Name: Tot Bwd Pkts_outliers, dtype: int64
# Tot Bwd Pkts_outliers
# 0    4002746
# 1      46166
# Name: Label, dtype: int64
# **********
# 0    639630
# 1       370
# Name: TotLen Fwd Pkts_outliers, dtype: int64
# TotLen Fwd Pkts_outliers
# 0    4047391
# 1       1521
# Name: Label, dtype: int64
# **********
# 0    639803
# 1       197
# Name: TotLen Bwd Pkts_outliers, dtype: int64
# TotLen Bwd Pkts_outliers
# 0    4048252
# 1        660
# Name: Label, dtype: int64
# **********
# 0    626852
# 1     13148
# Name: Fwd Pkt Len Max_outliers, dtype: int64
# Fwd Pkt Len Max_outliers
# 0    3942089
# 1     106823
# Name: Label, dtype: int64
# **********
# 0    639052
# 1       948
# Name: Fwd Pkt Len Min_outliers, dtype: int64
# Fwd Pkt Len Min_outliers
# 0    4042232
# 1       6680
# Name: Label, dtype: int64
# **********
# 0    621160
# 1     18840
# Name: Fwd Pkt Len Mean_outliers, dtype: int64
# Fwd Pkt Len Mean_outliers
# 0    3940066
# 1     108846
# Name: Label, dtype: int64
# **********
# 0    615617
# 1     24383
# Name: Fwd Pkt Len Std_outliers, dtype: int64
# Fwd Pkt Len Std_outliers
# 0    3916189
# 1     132723
# Name: Label, dtype: int64
# **********
# 0    639441
# 1       559
# Name: Bwd Pkt Len Max_outliers, dtype: int64
# Bwd Pkt Len Max_outliers
# 0    4044239
# 1       4673
# Name: Label, dtype: int64
# **********
# 0    639528
# 1       472
# Name: Bwd Pkt Len Min_outliers, dtype: int64
# Bwd Pkt Len Min_outliers
# 0    4043739
# 1       5173
# Name: Label, dtype: int64
# **********
# 0    637443
# 1      2557
# Name: Bwd Pkt Len Mean_outliers, dtype: int64
# Bwd Pkt Len Mean_outliers
# 0    4033105
# 1      15807
# Name: Label, dtype: int64
# **********
# 0    637626
# 1      2374
# Name: Bwd Pkt Len Std_outliers, dtype: int64
# Bwd Pkt Len Std_outliers
# 0    4033636
# 1      15276
# Name: Label, dtype: int64
# **********
# 0    635214
# 1      4786
# Name: Flow Byts/s_outliers, dtype: int64
# Flow Byts/s_outliers
# 0    4033949
# 1      14963
# Name: Label, dtype: int64
# **********
# 0    626049
# 1     13951
# Name: Flow Pkts/s_outliers, dtype: int64
# Flow Pkts/s_outliers
# 0    3925799
# 1     123113
# Name: Label, dtype: int64
# **********
# 0    628698
# 1     11302
# Name: Flow IAT Mean_outliers, dtype: int64
# Flow IAT Mean_outliers
# 0    3989619
# 1      59293
# Name: Label, dtype: int64
# **********
# 0    637307
# 1      2693
# Name: Flow IAT Std_outliers, dtype: int64
# Flow IAT Std_outliers
# 0    4029142
# 1      19770
# Name: Label, dtype: int64
# **********
# 0    629018
# 1     10982
# Name: Flow IAT Max_outliers, dtype: int64
# Flow IAT Max_outliers
# 0    3986296
# 1      62616
# Name: Label, dtype: int64
# **********
# 0    629240
# 1     10760
# Name: Flow IAT Min_outliers, dtype: int64
# Flow IAT Min_outliers
# 0    3993340
# 1      55572
# Name: Label, dtype: int64
# **********
# 0    629966
# 1     10034
# Name: Fwd IAT Tot_outliers, dtype: int64
# Fwd IAT Tot_outliers
# 0    3991678
# 1      57234
# Name: Label, dtype: int64
# **********
# 0    629553
# 1     10447
# Name: Fwd IAT Mean_outliers, dtype: int64
# Fwd IAT Mean_outliers
# 0    3993395
# 1      55517
# Name: Label, dtype: int64
# **********
# 0    637867
# 1      2133
# Name: Fwd IAT Std_outliers, dtype: int64
# Fwd IAT Std_outliers
# 0    4033329
# 1      15583
# Name: Label, dtype: int64
# **********
# 0    629020
# 1     10980
# Name: Fwd IAT Max_outliers, dtype: int64
# Fwd IAT Max_outliers
# 0    3986318
# 1      62594
# Name: Label, dtype: int64
# **********
# 0    629926
# 1     10074
# Name: Fwd IAT Min_outliers, dtype: int64
# Fwd IAT Min_outliers
# 0    3995788
# 1      53124
# Name: Label, dtype: int64
# **********
# 0    637600
# 1      2400
# Name: Bwd IAT Tot_outliers, dtype: int64
# Bwd IAT Tot_outliers
# 0    4030681
# 1      18231
# Name: Label, dtype: int64
# **********
# 0    637993
# 1      2007
# Name: Bwd IAT Mean_outliers, dtype: int64
# Bwd IAT Mean_outliers
# 0    4033148
# 1      15764
# Name: Label, dtype: int64
# **********
# 0    638236
# 1      1764
# Name: Bwd IAT Std_outliers, dtype: int64
# Bwd IAT Std_outliers
# 0    4035325
# 1      13587
# Name: Label, dtype: int64
# **********
# 0    637898
# 1      2102
# Name: Bwd IAT Max_outliers, dtype: int64
# Bwd IAT Max_outliers
# 0    4032363
# 1      16549
# Name: Label, dtype: int64
# **********
# 0    639291
# 1       709
# Name: Bwd IAT Min_outliers, dtype: int64
# Bwd IAT Min_outliers
# 0    4042562
# 1       6350
# Name: Label, dtype: int64
# **********
# 0    639631
# 1       369
# Name: Fwd Header Len_outliers, dtype: int64
# Fwd Header Len_outliers
# 0    4047402
# 1       1510
# Name: Label, dtype: int64
# **********
# 0    636246
# 1      3754
# Name: Bwd Header Len_outliers, dtype: int64
# Bwd Header Len_outliers
# 0    4002338
# 1      46574
# Name: Label, dtype: int64
# **********
# 0    625998
# 1     14002
# Name: Fwd Pkts/s_outliers, dtype: int64
# Fwd Pkts/s_outliers
# 0    3925470
# 1     123442
# Name: Label, dtype: int64
# **********
# 0    626074
# 1     13926
# Name: Bwd Pkts/s_outliers, dtype: int64
# Bwd Pkts/s_outliers
# 0    3926042
# 1     122870
# Name: Label, dtype: int64
# **********
# 0    639053
# 1       947
# Name: Pkt Len Min_outliers, dtype: int64
# Pkt Len Min_outliers
# 0    4042243
# 1       6669
# Name: Label, dtype: int64
# **********
# 0    639440
# 1       560
# Name: Pkt Len Max_outliers, dtype: int64
# Pkt Len Max_outliers
# 0    4044228
# 1       4684
# Name: Label, dtype: int64
# **********
# 0    637546
# 1      2454
# Name: Pkt Len Mean_outliers, dtype: int64
# Pkt Len Mean_outliers
# 0    4033019
# 1      15893
# Name: Label, dtype: int64
# **********
# 0    639490
# 1       510
# Name: Pkt Len Std_outliers, dtype: int64
# Pkt Len Std_outliers
# 0    4045274
# 1       3638
# Name: Label, dtype: int64
# **********
# 0    638956
# 1      1044
# Name: Pkt Len Var_outliers, dtype: int64
# Pkt Len Var_outliers
# 0    4042295
# 1       6617
# Name: Label, dtype: int64
# **********
# 0    639940
# 1        60
# Name: Down/Up Ratio_outliers, dtype: int64
# Down/Up Ratio_outliers
# 0    4048351
# 1        561
# Name: Label, dtype: int64
# **********
# 0    637215
# 1      2785
# Name: Pkt Size Avg_outliers, dtype: int64
# Pkt Size Avg_outliers
# 0    4031150
# 1      17762
# Name: Label, dtype: int64
# **********
# 0    621160
# 1     18840
# Name: Fwd Seg Size Avg_outliers, dtype: int64
# Fwd Seg Size Avg_outliers
# 0    3940066
# 1     108846
# Name: Label, dtype: int64
# **********
# 0    637443
# 1      2557
# Name: Bwd Seg Size Avg_outliers, dtype: int64
# Bwd Seg Size Avg_outliers
# 0    4033105
# 1      15807
# Name: Label, dtype: int64
# **********
# 0    639631
# 1       369
# Name: Subflow Fwd Pkts_outliers, dtype: int64
# Subflow Fwd Pkts_outliers
# 0    4047402
# 1       1510
# Name: Label, dtype: int64
# **********
# 0    639630
# 1       370
# Name: Subflow Fwd Byts_outliers, dtype: int64
# Subflow Fwd Byts_outliers
# 0    4047391
# 1       1521
# Name: Label, dtype: int64
# **********
# 0    636285
# 1      3715
# Name: Subflow Bwd Pkts_outliers, dtype: int64
# Subflow Bwd Pkts_outliers
# 0    4002746
# 1      46166
# Name: Label, dtype: int64
# **********
# 0    639803
# 1       197
# Name: Subflow Bwd Byts_outliers, dtype: int64
# Subflow Bwd Byts_outliers
# 0    4048252
# 1        660
# Name: Label, dtype: int64
# **********
# 0    612662
# 1     27338
# Name: Init Fwd Win Byts_outliers, dtype: int64
# Init Fwd Win Byts_outliers
# 0    3966594
# 1      82318
# Name: Label, dtype: int64
# **********
# 0    639710
# 1       290
# Name: Init Bwd Win Byts_outliers, dtype: int64
# Init Bwd Win Byts_outliers
# 0    4045833
# 1       3079
# Name: Label, dtype: int64
# **********
# 0    639631
# 1       369
# Name: Fwd Act Data Pkts_outliers, dtype: int64
# Fwd Act Data Pkts_outliers
# 0    4047402
# 1       1510
# Name: Label, dtype: int64
# **********
# 0    639069
# 1       931
# Name: Active Mean_outliers, dtype: int64
# Active Mean_outliers
# 0    4042276
# 1       6636
# Name: Label, dtype: int64
# **********
# 0    639464
# 1       536
# Name: Active Std_outliers, dtype: int64
# Active Std_outliers
# 0    4044316
# 1       4596
# Name: Label, dtype: int64
# **********
# 0    639085
# 1       915
# Name: Active Max_outliers, dtype: int64
# Active Max_outliers
# 0    4042312
# 1       6600
# Name: Label, dtype: int64
# **********
# 0    639122
# 1       878
# Name: Active Min_outliers, dtype: int64
# Active Min_outliers
# 0    4042641
# 1       6271
# Name: Label, dtype: int64
# **********
# 0    628851
# 1     11149
# Name: Idle Mean_outliers, dtype: int64
# Idle Mean_outliers
# 0    3985576
# 1      63336
# Name: Label, dtype: int64
# **********
# 0    639328
# 1       672
# Name: Idle Std_outliers, dtype: int64
# Idle Std_outliers
# 0    4043949
# 1       4963
# Name: Label, dtype: int64
# **********
# 0    628981
# 1     11019
# Name: Idle Max_outliers, dtype: int64
# Idle Max_outliers
# 0    3986119
# 1      62793
# Name: Label, dtype: int64
# **********
# 0    629338
# 1     10662
# Name: Idle Min_outliers, dtype: int64
# Idle Min_outliers
# 0    3989154
# 1      59758
# Name: Label, dtype: int64
# **********

# %% [markdown]
# # 特征选择

# %%
selector = VarianceThreshold(threshold=3)
selector = selector.fit(data[numerical_serial_fea])
features_mask = selector.get_support(indices=True)
selected_features = np.array(numerical_serial_fea)[features_mask]
print('Selected:', selected_features)
print('Deleted: ', [fea for fea in numerical_serial_fea if fea not in selected_features])
# Out:
# Selected: ['Dst Port' 'Flow Duration' 'Tot Fwd Pkts' 'Tot Bwd Pkts'
#  'TotLen Fwd Pkts' 'TotLen Bwd Pkts' 'Fwd Pkt Len Max' 'Fwd Pkt Len Min'
#  'Fwd Pkt Len Mean' 'Fwd Pkt Len Std' 'Bwd Pkt Len Max' 'Bwd Pkt Len Min'
#  'Bwd Pkt Len Mean' 'Bwd Pkt Len Std' 'Flow Byts/s' 'Flow Pkts/s'
#  'Flow IAT Mean' 'Flow IAT Std' 'Flow IAT Max' 'Flow IAT Min'
#  'Fwd IAT Tot' 'Fwd IAT Mean' 'Fwd IAT Std' 'Fwd IAT Max' 'Fwd IAT Min'
#  'Bwd IAT Tot' 'Bwd IAT Mean' 'Bwd IAT Std' 'Bwd IAT Max' 'Bwd IAT Min'
#  'Fwd Header Len' 'Bwd Header Len' 'Fwd Pkts/s' 'Bwd Pkts/s' 'Pkt Len Min'
#  'Pkt Len Max' 'Pkt Len Mean' 'Pkt Len Std' 'Pkt Len Var' 'Pkt Size Avg'
#  'Fwd Seg Size Avg' 'Bwd Seg Size Avg' 'Subflow Fwd Pkts'
#  'Subflow Fwd Byts' 'Subflow Bwd Pkts' 'Subflow Bwd Byts'
#  'Init Fwd Win Byts' 'Init Bwd Win Byts' 'Fwd Act Data Pkts' 'Active Mean'
#  'Active Std' 'Active Max' 'Active Min' 'Idle Mean' 'Idle Std' 'Idle Max'
#  'Idle Min']
# Deleted:  ['Down/Up Ratio']

# %%
pearsonr_result = []
for fea in numerical_serial_fea:
    pearsonr_result.append((fea, pearsonr(data[fea], data['Label'])))
sorted(pearsonr_result, key=lambda x: abs(x[1][0]), reverse=True)[:10]
# Out:
# [('Init Fwd Win Byts', (-0.6583273135868122, 0.0)),
#  ('Fwd Pkts/s', (0.25230978911459334, 0.0)),
#  ('Flow Pkts/s', (0.25228862335713786, 0.0)),
#  ('Bwd Pkts/s', (0.25091529186485223, 0.0)),
#  ('Pkt Len Var', (-0.2332686044709389, 0.0)),
#  ('Pkt Size Avg', (-0.22406734202303166, 0.0)),
#  ('Pkt Len Std', (-0.22405923451113813, 0.0)),
#  ('Bwd Pkt Len Std', (-0.2223618515373867, 0.0)),
#  ('Bwd Pkt Len Mean', (-0.21988225186136623, 0.0)),
#  ('Bwd Seg Size Avg', (-0.21988225186136623, 0.0))]

# %%
# find out the features can not be applied by chi2
for fea in [fea for fea in numerical_serial_fea if fea not in ['Init Fwd Win Byts', 'Init Bwd Win Byts']]:
    print(fea)
    print(chi2(np.array(data[fea]).reshape(-1, 1), np.array(data['Label']).reshape(-1, 1)))
# Out:
# Dst Port
# (array([2.70721692e+09]), array([0.]))
# Flow Duration
# (array([1.38375675e+13]), array([0.]))
# Tot Fwd Pkts
# (array([6.64963453e+10]), array([0.]))
# Tot Bwd Pkts
# (array([2384510.98170183]), array([0.]))
# TotLen Fwd Pkts
# (array([2.13320013e+12]), array([0.]))
# TotLen Bwd Pkts
# (array([1.1444004e+10]), array([0.]))
# Fwd Pkt Len Max
# (array([44979368.88079263]), array([0.]))
# Fwd Pkt Len Min
# (array([73241373.86480519]), array([0.]))
# Fwd Pkt Len Mean
# (array([11079204.52930162]), array([0.]))
# Fwd Pkt Len Std
# (array([16107228.00942219]), array([0.]))
# Bwd Pkt Len Max
# (array([93907824.32482651]), array([0.]))
# Bwd Pkt Len Min
# (array([11987019.23828791]), array([0.]))
# Bwd Pkt Len Mean
# (array([29950309.47130034]), array([0.]))
# Bwd Pkt Len Std
# (array([46063889.9574808]), array([0.]))
# Flow Byts/s
# (array([3.28014824e+10]), array([0.]))
# Flow Pkts/s
# (array([5.40274167e+11]), array([0.]))
# Flow IAT Mean
# (array([5.67402945e+12]), array([0.]))
# Flow IAT Std
# (array([3.94717593e+12]), array([0.]))
# Flow IAT Max
# (array([7.7690516e+12]), array([0.]))
# Flow IAT Min
# (array([5.76854696e+12]), array([0.]))
# Fwd IAT Tot
# (array([1.3937936e+13]), array([0.]))
# Fwd IAT Mean
# (array([6.43948089e+12]), array([0.]))
# Fwd IAT Std
# (array([9.89005353e+11]), array([0.]))
# Fwd IAT Max
# (array([7.55560125e+12]), array([0.]))
# Fwd IAT Min
# (array([6.57780345e+12]), array([0.]))
# Bwd IAT Tot
# (array([1.4659264e+13]), array([0.]))
# Bwd IAT Mean
# (array([1.57813023e+13]), array([0.]))
# Bwd IAT Std
# (array([2.21435773e+12]), array([0.]))
# Bwd IAT Max
# (array([1.22617801e+13]), array([0.]))
# Bwd IAT Min
# (array([2.33867851e+13]), array([0.]))
# Fwd Header Len
# (array([4.87777703e+11]), array([0.]))
# Bwd Header Len
# (array([62859938.46848986]), array([0.]))
# Fwd Pkts/s
# (array([2.59776945e+11]), array([0.]))
# Bwd Pkts/s
# (array([2.81355345e+11]), array([0.]))
# Pkt Len Min
# (array([75210340.70571806]), array([0.]))
# Pkt Len Max
# (array([94309920.80225748]), array([0.]))
# Pkt Len Mean
# (array([15912933.52440087]), array([0.]))
# Pkt Len Std
# (array([32357337.91096739]), array([0.]))
# Pkt Len Var
# (array([1.22967763e+10]), array([0.]))
# Down/Up Ratio
# (array([172082.67226082]), array([0.]))
# Pkt Size Avg
# (array([17575723.84743791]), array([0.]))
# Fwd Seg Size Avg
# (array([11079204.52930162]), array([0.]))
# Bwd Seg Size Avg
# (array([29950309.47130034]), array([0.]))
# Subflow Fwd Pkts
# (array([6.64963453e+10]), array([0.]))
# Subflow Fwd Byts
# (array([2.13320013e+12]), array([0.]))
# Subflow Bwd Pkts
# (array([2384510.98170183]), array([0.]))
# Subflow Bwd Byts
# (array([1.1444004e+10]), array([0.]))
# Fwd Act Data Pkts
# (array([6.85324767e+10]), array([0.]))
# Active Mean
# (array([7.52096993e+11]), array([0.]))
# Active Std
# (array([3.02750065e+11]), array([0.]))
# Active Max
# (array([9.39051934e+11]), array([0.]))
# Active Min
# (array([5.7146623e+11]), array([0.]))
# Idle Mean
# (array([6.96310394e+12]), array([0.]))
# Idle Std
# (array([3.89694777e+12]), array([0.]))
# Idle Max
# (array([8.13769443e+12]), array([0.]))
# Idle Min
# (array([6.38699571e+12]), array([0.]))

# %%
chi2_test_fea = [fea for fea in numerical_serial_fea if fea not in ['Init Fwd Win Byts', 'Init Bwd Win Byts']]
selector = SelectKBest(chi2, k=5)
selector = selector.fit(data[chi2_test_fea], data['Label'])
features_mask = selector.get_support(indices=True)
selected_features = np.array(chi2_test_fea)[features_mask]
print('Selected:', selected_features)
# Out:
# Selected: ['Flow Duration' 'Fwd IAT Tot' 'Bwd IAT Tot' 'Bwd IAT Mean' 'Bwd IAT Min']

# %%
selector = SelectKBest(mutual_info_classif, k=5)
selector = selector.fit(data[numerical_serial_fea], data['Label'])
features_mask = selector.get_support(indices=True)
selected_features = np.array(numerical_serial_fea)[features_mask]
print('Selected:', selected_features)
# Out:
# Selected: ['Flow Duration' 'Flow Pkts/s' 'Flow IAT Mean' 'Fwd Header Len'
#  'Init Fwd Win Byts']

# %%
features = [fea for fea in data.columns if fea not in ['Timestamp', 'Label']]
selector = RFE(DecisionTreeClassifier(), n_features_to_select=5, step=1)
selector = selector.fit(data[features], data['Label'])
features_mask = selector.get_support(indices=True)
selected_features = np.array(features)[features_mask]
print('Selected:', selected_features)
# Out:
# Selected: ['Flow Byts/s' 'Bwd Pkts/s' 'Init Fwd Win Byts' 'Init Bwd Win Byts'
#  'Fwd Seg Size Min']

# %%
selector = SelectFromModel(LogisticRegression(penalty='l2', C=10))
selector = selector.fit(data[features], data['Label'])
features_mask = selector.get_support(indices=True)
selected_features = np.array(features)[features_mask]
print('Selected:', selected_features)
# Out:
# Selected: ['Flow Duration' 'Flow Byts/s' 'Flow Pkts/s' 'Flow IAT Mean'
#  'Flow IAT Std' 'Flow IAT Max' 'Flow IAT Min' 'Fwd IAT Tot' 'Fwd IAT Mean'
#  'Fwd IAT Std' 'Fwd IAT Max' 'Fwd IAT Min' 'Bwd IAT Tot' 'Bwd IAT Mean'
#  'Bwd IAT Std' 'Bwd IAT Max' 'Bwd IAT Min' 'Fwd Pkts/s' 'Bwd Pkts/s'
#  'Pkt Len Var' 'Init Fwd Win Byts' 'Idle Mean' 'Idle Std' 'Idle Max'
#  'Idle Min']

# %%
selector = SelectFromModel(DecisionTreeClassifier())
selector = selector.fit(data[features], data['Label'])
features_mask = selector.get_support(indices=True)
selected_features = np.array(features)[features_mask]
print('Selected:', selected_features)
# Out:
# Selected: ['Dst Port' 'Flow Byts/s' 'Fwd IAT Min' 'Bwd Pkts/s' 'Init Fwd Win Byts'
#  'Init Bwd Win Byts' 'Fwd Seg Size Min']
